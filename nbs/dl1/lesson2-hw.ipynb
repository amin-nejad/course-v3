# %% [markdown]
# # Deploy model into production

# %% [markdown]
# For this homework, we will be deploying the model that we created into production. This is the Pneumonia detecting model which takes chest x-rays as input.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %%
from pathlib import Path

# %%
defaults.device = torch.device('cpu')

# %%
path = Path('/home/jupyter/tutorials/data/chest_xray')

# %%
img = open_image(path/'test'/'NORMAL'/'IM-0111-0001.jpeg')
#img = open_image(path/'test'/'UNRELATED'/'12676_1.jpg')
img
# Out:
# Image (3, 1303, 1910)

# %%
learn = load_learner(path/'train_val')

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category normal

# %%
results = dict(zip(learn.data.classes,list(outputs)))

# %%
df_results = pd.DataFrame.from_dict(results, orient='index', columns=['probability'])

# %%
df_results
# Out:
#           probability
# bacteria     0.000545
# normal       0.987167
# virus        0.012288
