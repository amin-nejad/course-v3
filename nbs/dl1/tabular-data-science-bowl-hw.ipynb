# %% [markdown]
# # Tabular models

# %%
from fastai.tabular import *
from pathlib import Path
from sklearn.metrics import cohen_kappa_score

# %%
def sklearn_qwk(y_true, y_pred) -> np.float64:
    """
    Function for measuring Quadratic Weighted Kappa with scikit-learn
    
    :param y_true: The ground truth labels
    :param y_pred: Our predicted labels
    
    :return The Quadratic Weighted Kappa Score (QWK)
    """
    return cohen_kappa_score(y_true, y_pred, weights="quadratic")

# %% [markdown]
# Tabular data should be in a Pandas `DataFrame`.

# %%
path = Path('/home/jupyter/tutorials/data/data-science-bowl-2019')

specs = pd.read_csv(path/'specs.csv')
sample_submission = pd.read_csv(path/'sample_submission.csv')
test = pd.read_csv(path/'test.csv')
train = pd.read_csv(path/'train.csv')
train_labels = pd.read_csv(path/'train_labels.csv')

# %% [markdown]
# The outcomes in this competition are grouped into 4 groups (labeled accuracy_group in the data):
#
#     3: the assessment was solved on the first attempt
#     2: the assessment was solved on the second attempt
#     1: the assessment was solved after 3 or more attempts
#     0: the assessment was never solved

# %%
df_summary = train_labels.groupby('accuracy_group').count()
df_summary.game_session.nlargest(10)
# Out:
# accuracy_group
# 3    8845
# 0    4229
# 1    2411
# 2    2205
# Name: game_session, dtype: int64

# %%
sample_submission
# Out:
#     installation_id  accuracy_group
# 0          00abaee7               3
# 1          01242218               3
# 2          017c5718               3
# 3          01a44906               3
# 4          01bc6cb6               3
# ..              ...             ...
# 995        fee254cf               3
# 996        ff57e602               3
# 997        ffc73fb2               3
# 998        ffe00ca8               3
# 999        ffe774cc               3
#
# [1000 rows x 2 columns]

# %% [markdown]
# The groups are imbalanced as approximately 1/2 of the activities were solved on the first attempt. Approximately 1/4 were never solved whilst the remained are evenly balanced between those taking 1 attempt and those taking 2.

# %%
train_labels.title.unique()
# Out:
# array(['Mushroom Sorter (Assessment)', 'Bird Measurer (Assessment)', 'Cauldron Filler (Assessment)',
#        'Chest Sorter (Assessment)', 'Cart Balancer (Assessment)'], dtype=object)

# %%
train_labels = train_labels[['game_session','accuracy_group']]
train_labels
# Out:
#            game_session  accuracy_group
# 0      6bdf9623adc94d89               3
# 1      77b8ee947eb84b4e               0
# 2      901acc108f55a5a1               3
# 3      9501794defd84e4d               2
# 4      a9ef3ecb3d1acc6a               3
# ...                 ...             ...
# 17685  c996482b11d149dd               3
# 17686  b05a02b52d5c1f4c               3
# 17687  5448d652309a6324               1
# 17688  a6885ab824fbc32c               0
# 17689  dadd1a4d8ac68ab0               1
#
# [17690 rows x 2 columns]

# %%
test[(test.installation_id == 'ffe774cc') & (test.type == 'Assessment')]
# Out:
#          event_id      game_session                 timestamp  \
# 1156371  3bfd1a65  46ff9d3ad2be09f2  2019-09-28T21:20:08.980Z
# 1156372  db02c830  46ff9d3ad2be09f2  2019-09-28T21:20:09.273Z
# 1156373  a1e4395d  46ff9d3ad2be09f2  2019-09-28T21:20:09.325Z
# 1156374  a52b92d5  46ff9d3ad2be09f2  2019-09-28T21:20:13.338Z
# 1156375  a1e4395d  46ff9d3ad2be09f2  2019-09-28T21:20:13.348Z
# 1156376  28ed704e  46ff9d3ad2be09f2  2019-09-28T21:20:14.631Z
# 1156372  {"event_count":2,"game_time":248,"event_code":...        ffe774cc
# 1156373  {"description":"Pull three mushrooms out of th...        ffe774cc
# 1156374  {"description":"Pull three mushrooms out of th...        ffe774cc
# 1156375  {"description":"To pick a mushroom, pull it ou...        ffe774cc
# 1156376  {"height":3,"coordinates":{"x":832,"y":464,"st...        ffe774cc
# 1156377  {"description":"To pick a mushroom, pull it ou...        ffe774cc
# 1156378  {"description":"That's one!","identifier":"Dot...        ffe774cc
# 1156379  {"description":"That's one!","identifier":"Dot...        ffe774cc
# 1156380  {"coordinates":{"x":951,"y":453,"stage_width":...        ffe774cc
# 1156381  {"coordinates":{"x":861,"y":576,"stage_width":...        ffe774cc
# 1156382  {"height":4,"coordinates":{"x":323,"y":541,"st...        ffe774cc
# 1156383  {"description":"two...","identifier":"Dot_Two"...        ffe774cc
# 1156384  {"description":"two...","identifier":"Dot_Two"...        ffe774cc
# 1156385  {"coordinates":{"x":564,"y":509,"stage_width":...        ffe774cc
# 1156386  {"coordinates":{"x":562,"y":504,"stage_width":...        ffe774cc
# 1156387  {"coordinates":{"x":562,"y":505,"stage_width":...        ffe774cc
# 1156388  {"coordinates":{"x":540,"y":505,"stage_width":...        ffe774cc
# 1156389  {"height":2,"coordinates":{"x":538,"y":488,"st...        ffe774cc
# 1156390  {"description":"and three!","identifier":"Dot_...        ffe774cc
# 1156391  {"description":"and three!","identifier":"Dot_...        ffe774cc
# 1156392  {"event_count":23,"game_time":12576,"event_cod...        ffe774cc
# 1156393  {"duration":12328,"event_count":22,"game_time"...        ffe774cc
# 1156394  {"description":"Now order these mushrooms by h...        ffe774cc
# 1156395  {"description":"Now order these mushrooms by h...        ffe774cc
# 1156396  {"height":2,"stumps":[0,0,0],"coordinates":{"x...        ffe774cc
# 1156397  {"height":2,"destination":"middle","stumps":[0...        ffe774cc
# 1156398  {"height":2,"stumps":[0,0,0],"coordinates":{"x...        ffe774cc
# 1156399  {"height":2,"destination":"left","stumps":[2,0...        ffe774cc
# 1156400  {"height":4,"stumps":[2,0,0],"coordinates":{"x...        ffe774cc
# 1156401  {"height":4,"destination":"right","stumps":[2,...        ffe774cc
# 1156402  {"coordinates":{"x":795,"y":492,"stage_width":...        ffe774cc
# 1156403  {"height":3,"stumps":[2,0,4],"coordinates":{"x...        ffe774cc
# 1156404  {"height":3,"destination":"middle","stumps":[2...        ffe774cc
# 1156405  {"description":"Okay, when you want to check y...        ffe774cc
# 1156406  {"correct":true,"stumps":[2,3,4],"event_count"...        ffe774cc
# 1156407  {"description":"Okay, when you want to check y...        ffe774cc
# 1156408  {"description":"Alright! This one is the littl...        ffe774cc
# 1156409  {"description":"Alright! This one is the littl...        ffe774cc
# 1156410  {"duration":20008,"misses":0,"event_count":40,...        ffe774cc
# 1156411  {"session_duration":36607,"exit_type":"game_co...        ffe774cc
# 1156413  {"version":"1.0","event_count":1,"game_time":0...        ffe774cc
#
#          event_count  event_code  game_time                         title  \
# 1156371            1        2000          0  Mushroom Sorter (Assessment)
# 1156372            2        2025        248  Mushroom Sorter (Assessment)
# 1156373            3        3010        248  Mushroom Sorter (Assessment)
# 1156393  Assessment  TREETOPCITY
# 1156394  Assessment  TREETOPCITY
# 1156395  Assessment  TREETOPCITY
# 1156396  Assessment  TREETOPCITY
# 1156397  Assessment  TREETOPCITY
# 1156398  Assessment  TREETOPCITY
# 1156399  Assessment  TREETOPCITY
# 1156400  Assessment  TREETOPCITY
# 1156401  Assessment  TREETOPCITY
# 1156402  Assessment  TREETOPCITY
# 1156403  Assessment  TREETOPCITY
# 1156404  Assessment  TREETOPCITY
# 1156405  Assessment  TREETOPCITY
# 1156406  Assessment  TREETOPCITY
# 1156407  Assessment  TREETOPCITY
# 1156408  Assessment  TREETOPCITY
# 1156409  Assessment  TREETOPCITY
# 1156410  Assessment  TREETOPCITY
# 1156411  Assessment  TREETOPCITY
# 1156413  Assessment  TREETOPCITY

# %%
train = train.merge(train_labels,how='left',on='game_session')

# %%
installations = list(train.installation_id[~train.accuracy_group.isna()].unique())
len(installations)
# Out:
# 3614

# %%
train = train[train.installation_id.isin(installations)]
train
# Out:
#           event_id      game_session                 timestamp  \
# 1538      27253bdc  34ba1a28d02ba8ba  2019-08-06T04:57:18.904Z
# 1539      27253bdc  4b57c9a59474a1b9  2019-08-06T04:57:45.301Z
# 1540      77261ab5  2b9d5af79bcdb79f  2019-08-06T04:58:14.538Z
# 1541      b2dba42b  2b9d5af79bcdb79f  2019-08-06T04:58:14.615Z
# 1542      1325467d  2b9d5af79bcdb79f  2019-08-06T04:58:16.680Z
# ...            ...               ...                       ...
# 11337821  28520915  5448d652309a6324  2019-09-22T02:07:27.562Z
# 11337822  91561152  5448d652309a6324  2019-09-22T02:07:27.562Z
# 11337823  d3268efa  5448d652309a6324  2019-09-22T02:07:27.566Z
# 11337824  b5053438  5448d652309a6324  2019-09-22T02:07:28.311Z
# 11337825  2b058fe3  5448d652309a6324  2019-09-22T02:07:31.963Z
#
#                                                  event_data installation_id  \
# 1538                 {"event_code": 2000, "event_count": 1}        0006a69f
# 1539                 {"event_code": 2000, "event_count": 1}        0006a69f
# 1540      {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 1541      {"description":"Let's build a sandcastle! Firs...        0006a69f
# 1542      {"coordinates":{"x":273,"y":650,"stage_width":...        0006a69f
# ...                                                     ...             ...
# 11337821  {"misses":1,"prompt":"holds least","mode":"sel...        ffeb0b1b
# 11337822  {"bucket":1,"buckets_placed":[3,1,2],"target_b...        ffeb0b1b
# 11337823  {"description":"Awesome.","identifier":"Dot_Aw...        ffeb0b1b
# 11337824  {"description":"Awesome.","identifier":"Dot_Aw...        ffeb0b1b
# 11337825  {"session_duration":71511,"event_count":61,"ga...        ffeb0b1b
#
#           event_count  event_code  game_time                          title  \
# 1538                1        2000          0        Welcome to Lost Lagoon!
# 1539                1        2000          0           Magma Peak - Level 1
# 1540                1        2000          0  Sandcastle Builder (Activity)
# 1541                2        3010         29  Sandcastle Builder (Activity)
# 1542                3        4070       2137  Sandcastle Builder (Activity)
# ...               ...         ...        ...                            ...
# 11337821           58        2030      67094   Cauldron Filler (Assessment)
# 11337822           57        4025      67094   Cauldron Filler (Assessment)
# 11337823           59        3021      67094   Cauldron Filler (Assessment)
# 11337824           60        3121      67847   Cauldron Filler (Assessment)
# 11337825           61        2010      71511   Cauldron Filler (Assessment)
#
#                 type      world  accuracy_group
# 1538            Clip       NONE             NaN
# 1539            Clip  MAGMAPEAK             NaN
# 1540        Activity  MAGMAPEAK             NaN
# 1541        Activity  MAGMAPEAK             NaN
# 1542        Activity  MAGMAPEAK             NaN
# ...              ...        ...             ...
# 11337821  Assessment  MAGMAPEAK             1.0
# 11337822  Assessment  MAGMAPEAK             1.0
# 11337823  Assessment  MAGMAPEAK             1.0
# 11337824  Assessment  MAGMAPEAK             1.0
# 11337825  Assessment  MAGMAPEAK             1.0
#
# [7734558 rows x 12 columns]

# %% [markdown]
# Verifying each game session only has 1 game at a time on there.

# %%
g = train.groupby('game_session').agg({'title': lambda x: len(x.unique())})
g.title.nlargest(4)
# Out:
#                                           title
# game_session
# 000050630c4b081b                     Dino Drink
# 00005be8058d8e35                  Balancing Act
# 0000d473b2f78883  Sandcastle Builder (Activity)
# 0000e00444c302d9           Magma Peak - Level 1
# 00011d7f4b48ed4b        Crystal Caves - Level 3
# ...                                         ...
# fffda980b07029a3      Flower Waterer (Activity)
# fffe19a8d3973f9d        Tree Top City - Level 1
# fffe897c0216edaf                    Costume Box
# fffe9cd0cc5b076b                    Leaf Leader
# fffebbb01855e28b                     Dino Drink
#
# [175467 rows x 1 columns]

# %%
final = train.groupby('game_session').agg({'timestamp':'min', 
                                           'title':'min', 
                                           'accuracy_group':'min',
                                           'installation_id':'min'})

# %%
final.dropna(inplace=True)
final.sort_values(by=['installation_id', 'timestamp'],inplace=True)
train.sort_values(by=['installation_id', 'timestamp'],inplace=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
final
# Out:
#                                  timestamp                         title  \
# game_session
# 901acc108f55a5a1  2019-08-06T05:22:01.344Z  Mushroom Sorter (Assessment)
# 77b8ee947eb84b4e  2019-08-06T05:35:19.167Z    Bird Measurer (Assessment)
# 6bdf9623adc94d89  2019-08-06T05:37:50.020Z  Mushroom Sorter (Assessment)
# 9501794defd84e4d  2019-08-06T20:34:53.812Z  Mushroom Sorter (Assessment)
# a9ef3ecb3d1acc6a  2019-08-06T20:49:59.095Z    Bird Measurer (Assessment)
# ...                                    ...                           ...
# 460e8bdc2822b340  2019-07-30T12:12:49.516Z     Chest Sorter (Assessment)
# b05a02b52d5c1f4c  2019-08-07T01:06:38.407Z  Cauldron Filler (Assessment)
# dadd1a4d8ac68ab0  2019-09-09T15:34:41.704Z  Cauldron Filler (Assessment)
# a6885ab824fbc32c  2019-09-22T01:58:20.095Z  Mushroom Sorter (Assessment)
# 5448d652309a6324  2019-09-22T02:06:20.595Z  Cauldron Filler (Assessment)
#
#                   accuracy_group installation_id
# game_session
# 901acc108f55a5a1             3.0        0006a69f
# 77b8ee947eb84b4e             0.0        0006a69f
# 6bdf9623adc94d89             3.0        0006a69f
# 9501794defd84e4d             2.0        0006a69f
# a9ef3ecb3d1acc6a             3.0        0006a69f
# ...                          ...             ...
# 460e8bdc2822b340             3.0        ffc90c32
# b05a02b52d5c1f4c             3.0        ffd2871d
# dadd1a4d8ac68ab0             1.0        ffeb0b1b
# a6885ab824fbc32c             0.0        ffeb0b1b
# 5448d652309a6324             1.0        ffeb0b1b
#
# [17690 rows x 4 columns]

# %%
dep_var = 'salary'
cat_names = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race']
cont_names = ['age', 'fnlwgt', 'education-num']
procs = [FillMissing, Categorify, Normalize]

# %%
test = TabularList.from_df(df.iloc[800:1000].copy(), path=path, cat_names=cat_names, cont_names=cont_names)

# %%
data = (TabularList.from_df(df, path=path, cat_names=cat_names, cont_names=cont_names, procs=procs)
                           .split_by_idx(list(range(800,1000)))
                           .label_from_df(cols=dep_var)
                           .add_test(test)
                           .databunch())

# %%
data.show_batch(rows=10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>workclass</th>
#       <th>education</th>
#       <th>marital-status</th>
#       <th>occupation</th>
#       <th>relationship</th>
#       <th>race</th>
#       <th>education-num_na</th>
#       <th>age</th>
#       <th>fnlwgt</th>
#       <th>education-num</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Local-gov</td>
#       <td>HS-grad</td>
#       <td>Married-civ-spouse</td>
#       <td>Transport-moving</td>
#       <td>Husband</td>
#       <td>White</td>
#       <td>False</td>
#       <td>1.2030</td>
#       <td>-0.2910</td>
#       <td>-0.4224</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <td>Private</td>
#       <td>Some-college</td>
#       <td>Never-married</td>
#       <td>Adm-clerical</td>
#       <td>Own-child</td>
#       <td>White</td>
#       <td>False</td>
#       <td>-1.4357</td>
#       <td>0.7079</td>
#       <td>-0.0312</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <td>Self-emp-not-inc</td>
#       <td>Some-college</td>
#       <td>Married-civ-spouse</td>
#       <td>Sales</td>
#       <td>Husband</td>
#       <td>White</td>
#       <td>False</td>
#       <td>1.7161</td>
#       <td>0.1362</td>
#       <td>-0.0312</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <td>Private</td>
#       <td>Some-college</td>
#       <td>Widowed</td>
#       <td>Other-service</td>
#       <td>Unmarried</td>
#       <td>White</td>
#       <td>False</td>
#       <td>1.9360</td>
#       <td>0.5105</td>
#       <td>-0.0312</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <td>Private</td>
#       <td>Some-college</td>
#       <td>Separated</td>
#       <td>Adm-clerical</td>
#       <td>Unmarried</td>
#       <td>Black</td>
#       <td>False</td>
#       <td>-0.6294</td>
#       <td>-0.1218</td>
#       <td>-0.0312</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <td>Federal-gov</td>
#       <td>Bachelors</td>
#       <td>Never-married</td>
#       <td>Exec-managerial</td>
#       <td>Not-in-family</td>
#       <td>White</td>
#       <td>False</td>
#       <td>0.4701</td>
#       <td>1.8052</td>
#       <td>1.1422</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <td>Private</td>
#       <td>Assoc-voc</td>
#       <td>Married-civ-spouse</td>
#       <td>Adm-clerical</td>
#       <td>Husband</td>
#       <td>White</td>
#       <td>False</td>
#       <td>0.5434</td>
#       <td>0.4552</td>
#       <td>0.3599</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <td>Private</td>
#       <td>10th</td>
#       <td>Married-civ-spouse</td>
#       <td>Sales</td>
#       <td>Husband</td>
#       <td>White</td>
#       <td>False</td>
#       <td>0.4701</td>
#       <td>-0.7334</td>
#       <td>-1.5958</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <td>Private</td>
#       <td>HS-grad</td>
#       <td>Never-married</td>
#       <td>Machine-op-inspct</td>
#       <td>Not-in-family</td>
#       <td>White</td>
#       <td>False</td>
#       <td>-0.5561</td>
#       <td>1.3525</td>
#       <td>-0.4224</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <td>Private</td>
#       <td>9th</td>
#       <td>Married-civ-spouse</td>
#       <td>Transport-moving</td>
#       <td>Husband</td>
#       <td>White</td>
#       <td>False</td>
#       <td>1.7894</td>
#       <td>-0.8497</td>
#       <td>-1.9869</td>
#       <td>&lt;50k</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn = tabular_learner(data, layers=[200,100], metrics=accuracy)

# %%
learn.fit(5, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.372202</td>
#       <td>0.385182</td>
#       <td>0.845000</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.351467</td>
#       <td>0.383389</td>
#       <td>0.820000</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.353323</td>
#       <td>0.363336</td>
#       <td>0.825000</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.368288</td>
#       <td>0.365168</td>
#       <td>0.830000</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.357279</td>
#       <td>0.356136</td>
#       <td>0.835000</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Inference

# %%
row = df.iloc[0]

# %%
learn.predict(row)
# Out:
# (Category <50k, tensor(0), tensor([0.5045, 0.4955]))
